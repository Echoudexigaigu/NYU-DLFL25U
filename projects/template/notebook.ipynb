# %% [markdown]
# # Project title
#
# ## 1. Conceptual question
# State the deep learning concept being investigated.
# This must be a conceptual question, not an application.
#
# Example:
# > Does max-pooling introduce translation invariance in CNNs?
#
# ---
#
# ## 2. Hypothesis
# State one precise, falsifiable hypothesis.
#
# - The hypothesis must be refutable by the experiment.
# - Avoid vague or qualitative claims.
#
# Example:
# > Networks with max-pooling are more robust to small input translations than networks without pooling.
#
# ---
#
# ## 3. Experimental design
# Describe how the experiment tests the hypothesis.
#
# Explicitly answer:
# - What is being compared?
# - What is kept fixed?
# - What is varied?
# - Why this experiment is sufficient to test the hypothesis
#
# No results or interpretation here.
#
# ---
#
# ## 4. Experiment code
# Code used to generate the results.
#
# Rules:
# - Minimal and purpose-driven
# - No pre-trained models
# - No hyperparameter search unless conceptually motivated
#
# ```python
# # experiment code
# ```
